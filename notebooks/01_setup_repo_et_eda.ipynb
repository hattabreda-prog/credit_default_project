# %% [markdown]
# La variable predicted_default_payment_next_month correspond à une prédiction du défaut de paiement. Elle ne doit pas être utilisée comme variable explicative. Elle contient une information dérivée de la variable cible default_payment_next_month. Son utilisation introduirait une fuite de données (data leakage) et conduirait à une estimation artificiellement optimiste des performances du modèle.

# %%
df.groupby("marital_status")["default_payment_next_month"].mean()
# Out:
# marital_status
# 0    0.000000
# 1    0.226727
# 2    0.205144
# 3    0.171429
# Name: default_payment_next_month, dtype: float64

# %%
df.groupby("education_level")["default_payment_next_month"].mean()
# Out:
# education_level
# 0    0.000000
# 1    0.170356
# 2    0.244286
# 3    0.233954
# 4    0.000000
# 5    0.041667
# 6    0.500000
# Name: default_payment_next_month, dtype: float64

# %%
df.groupby("sex")["default_payment_next_month"].mean()
# Out:
# sex
# 1    0.225279
# 2    0.206992
# Name: default_payment_next_month, dtype: float64

# %%
df["default_payment_next_month"].value_counts(normalize=True)
# Out:
# default_payment_next_month
# 0    0.785835
# 1    0.214165
# Name: proportion, dtype: float64

# %%
counts = df["default_payment_next_month"].value_counts().sort_index()

plt.figure()
plt.bar(counts.index.astype(str), counts.values)
plt.title("Distribution du défaut de paiement")
plt.xlabel("default_payment_next_month")
plt.ylabel("Nombre d'observations")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
counts = df["default_payment_next_month"].value_counts().sort_index()

plt.figure()
plt.bar(counts.index.astype(str), counts.values)
plt.title("Distribution du défaut de paiement")
plt.xlabel("default_payment_next_month")
plt.ylabel("Nombre d'observations")
plt.show()

# %%
df["default_payment_next_month"].value_counts(normalize=True)
# Out:
# default_payment_next_month
# 0    0.785835
# 1    0.214165
# Name: proportion, dtype: float64

# %%
df["default_payment_next_month"].value_counts()
# Out:
# default_payment_next_month
# 0    2330
# 1     635
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# id                                      0
# limit_balance                           0
# sex                                     0
# education_level                         0
# marital_status                          0
# age                                     0
# pay_0                                   0
# pay_2                                   0
# pay_3                                   0
# pay_4                                   0
# pay_5                                   0
# pay_6                                   0
# bill_amt_1                              0
# bill_amt_2                              0
# bill_amt_3                              0
# bill_amt_4                              0
# bill_amt_5                              0
# bill_amt_6                              0
# pay_amt_1                               0
# pay_amt_2                               0
# pay_amt_3                               0
# pay_amt_4                               0
# ...

# %%
df.columns
# Out:
# Index(['id', 'limit_balance', 'sex', 'education_level', 'marital_status',
#        'age', 'pay_0', 'pay_2', 'pay_3', 'pay_4', 'pay_5', 'pay_6',
#        'bill_amt_1', 'bill_amt_2', 'bill_amt_3', 'bill_amt_4', 'bill_amt_5',
#        'bill_amt_6', 'pay_amt_1', 'pay_amt_2', 'pay_amt_3', 'pay_amt_4',
#        'pay_amt_5', 'pay_amt_6', 'default_payment_next_month',
#        'predicted_default_payment_next_month'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                                      float64
# limit_balance                           float64
# sex                                       int64
# education_level                           int64
# marital_status                            int64
# age                                     float64
# pay_0                                   float64
# pay_2                                   float64
# pay_3                                   float64
# pay_4                                   float64
# pay_5                                     int64
# pay_6                                     int64
# bill_amt_1                              float64
# bill_amt_2                              float64
# bill_amt_3                              float64
# bill_amt_4                              float64
# bill_amt_5                              float64
# bill_amt_6                              float64
# pay_amt_1                               float64
# pay_amt_2                               float64
# ...

# %%
df.shape
# Out:
# (2965, 26)

# %%
DATA_PATH = "../data/raw/credit_card_default.csv"

df = pd.read_csv(DATA_PATH)

df.head()
# Out:
#         id  limit_balance  sex  education_level  marital_status   age  pay_0  \
# 0  27502.0        80000.0    1                6               1  54.0    0.0
# 1  26879.0       200000.0    1                4               1  49.0    0.0
# 2  18340.0        20000.0    2                6               2  22.0    0.0
# 3  13692.0       260000.0    2                4               2  33.0    0.0
# 4  20405.0       150000.0    1                4               2  32.0    0.0
#
#    pay_2  pay_3  pay_4  ...  bill_amt_5  bill_amt_6  pay_amt_1  pay_amt_2  \
# 0    0.0    0.0    0.0  ...     26210.0     17643.0     2545.0     2208.0
# 1    0.0    0.0    0.0  ...     50235.0     48984.0     1689.0     2164.0
# 2    0.0    0.0    0.0  ...       500.0         0.0     4641.0     1019.0
# 3    0.0    0.0    0.0  ...     30767.0     29890.0     5000.0     5000.0
# 4    0.0    0.0   -1.0  ...    143375.0    146411.0     4019.0   146896.0
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.
